# %%
import numpy as np 
# Definir la lista original
puntos = [5, 1, 4, 7, 0]

# Usar la función sorted() para obtener el orden de los elementos
orden = sorted(range(len(puntos)), key=lambda x: puntos[x])

# Imprimir el orden
print(orden)
# Out:
# [4, 1, 2, 0, 3]

# %%
def vec_2points(p1, p2):
    return (p2[0] - p1[0], p2[1] - p1[1])

def cross_product(vec1, vec2):
    return vec1[0] * vec2[1] - vec1[1] * vec2[0]

def which_side(p1, p2, p):
    vec1 = vec_2points(p1, p2)
    vec2 = vec_2points(p1, p)
    cross_p = cross_product(vec1, vec2)
    if cross_p > 0:
        return 1 #Right
    elif cross_p < 0:
        return -1 #Left
    else: 
        return 0 #On the line

# %%
p1 = [0, -1, 0]
p2 = [0, 1, 0]
p = [1, 1, 0]

# %%
which_side(p2, p1, p)
# Out:
# 1

# %%
import bisect

import bisect

class Event:
    def __init__(self, x, segment, event_type):
        self.x = x
        self.segment = segment
        self.event_type = event_type  # 'start' or 'end'

    def __lt__(self, other):
        if self.x != other.x:
            return self.x < other.x
        # Si dos eventos ocurren en el mismo punto,
        # se da prioridad a los eventos de inicio sobre los eventos de fin.
        return self.event_type == 'start' and other.event_type == 'end'

def insert_event(events, new_event):
    bisect.insort_left(events, new_event)

def remove_event(events, event_to_remove):
    events.remove(event_to_remove)

# Ejemplo de uso
events = []
event1 = Event(3, ((1, 1), (4, 4)), 'start')
event2 = Event(5, ((2, 2), (5, 5)), 'end')
event3 = Event(2, ((3, 1), (1, 3)), 'start')

insert_event(events, event1)
insert_event(events, event2)
insert_event(events, event3)

print("Eventos antes de la eliminación:")
for event in events:
    print("Coordenada x:", event.x)
    print("Segmento:", event.segment)
    print("Tipo de evento:", event.event_type)
    print()

remove_event(events, event2)

print("\nEventos después de la eliminación:")
for event in events:
    print("Coordenada x:", event.x)
    print("Segmento:", event.segment)
    print("Tipo de evento:", event.event_type)
    print()
# Out:
# Eventos antes de la eliminación:
# Coordenada x: 2
# Segmento: ((3, 1), (1, 3))
# Tipo de evento: start
#
# Coordenada x: 3
# Segmento: ((1, 1), (4, 4))
# Tipo de evento: start
#
# Coordenada x: 5
# Segmento: ((2, 2), (5, 5))
# Tipo de evento: end
#
#
# Eventos después de la eliminación:
# Coordenada x: 2
# Segmento: ((3, 1), (1, 3))
# Tipo de evento: start
#
# Coordenada x: 3
# Segmento: ((1, 1), (4, 4))
# Tipo de evento: start

# %%
def vec_2points(p1, p2):
    return (p2[0] - p1[0], p2[1] - p1[1])

def cross_product(vec1, vec2):
    return vec1[0] * vec2[1] - vec1[1] * vec2[0]

# Ve de que lado esta el punto p, respecto a la recta formada por p1, p2
def which_side(p1, p2, p):
    vec1 = vec_2points(p1, p2)
    vec2 = vec_2points(p1, p)
    cross_p = cross_product(vec1, vec2)
    if cross_p > 0:
        return 1 # Right
    elif cross_p < 0:
        return -1 # Left
    else: 
        return 0 # On the line

# %%
import random

# Necesito una referencia entre el nombre del segmento y los nodos para poder hacer el swap correctamente
nodos_por_clave = {}

def agregar_nodo(clave, p1, p2, prioridad=None, padre=None):
    nuevo_nodo = Nodo(clave, p1, p2, prioridad, padre)
    # Aquí asumimos que la clave es única para cada nodo
    nodos_por_clave[clave] = nuevo_nodo

    return nuevo_nodo

class Nodo:
    def __init__(self, clave, p1, p2, prioridad=None, padre=None):
        self.clave = clave # El nombre del segmento
        self.p1 = p1 # El punto que marca el inicio del segmento
        self.p2 = p2 # El punto que marca el fin del segmento
        self.prioridad = prioridad if prioridad is not None else random.random()
        self.izquierda = None
        self.derecha = None
        self.padre = padre

class Treap:
    def __init__(self):
        self.raiz = None

    def insertar(self, clave, p1, p2, prioridad=None):
        if not self.raiz:
            self.raiz = agregar_nodo(clave, p1, p2, prioridad)
        else:
            self.raiz = self._insertar(self.raiz, clave, p1, p2, prioridad)

    def _insertar(self, nodo, clave, p1, p2, prioridad):
        if not nodo:
            return agregar_nodo(clave, p1, p2, prioridad)

        position = which_side(nodo.p1, nodo.p2, p1)
        if position != -1: # Si el inicio del segmento esta a la izq 
            nodo.izquierda = self._insertar(nodo.izquierda, clave, p1, p2, prioridad)
            nodo.izquierda.padre = nodo
            if nodo.izquierda.prioridad > nodo.prioridad:
                nodo = self.rotar_derecha(nodo)
        else: # Si el inicio del segmento esta a la der
            nodo.derecha = self._insertar(nodo.derecha, clave, p1, p2, prioridad)
            nodo.derecha.padre = nodo
            if nodo.derecha.prioridad > nodo.prioridad:
                nodo = self.rotar_izquierda(nodo)
        return nodo

    def rotar_derecha(self, y):
        x = y.izquierda
        T2 = x.derecha
        x.derecha = y
        y.izquierda = T2
        x.padre = y.padre  # Actualizar el padre de x
        y.padre = x  # El nuevo padre de y es x
        if T2: T2.padre = y  # Actualizar el padre de T2, si existe
        return x

    def rotar_izquierda(self, x):
        y = x.derecha
        T2 = y.izquierda
        y.izquierda = x
        x.derecha = T2
        y.padre = x.padre  # Actualizar el padre de y
        x.padre = y  # El nuevo padre de x es y
        if T2: T2.padre = x  # Actualizar el padre de T2, si existe
        return y
    
    def eliminar(self, clave):
        if clave in nodos_por_clave:
            nodo_a_eliminar = nodos_por_clave[clave]
            self._eliminar(nodo_a_eliminar)
            del nodos_por_clave[clave]  # Eliminar el nodo del diccionario
        

    # Checa como entender esto, para ver si la eliminacion se hace correcta
    def _eliminar(self, nodo):
        # Eliminar un nodo con 0 o 1 hijo es directo: reemplazarlo con su hijo (si lo tiene)
        if not nodo.izquierda or not nodo.derecha:
            hijo = nodo.izquierda if nodo.izquierda else nodo.derecha
            if nodo == self.raiz:
                self.raiz = hijo
                if hijo: hijo.padre = None
            elif nodo.padre.izquierda == nodo:
                nodo.padre.izquierda = hijo
                if hijo: hijo.padre = nodo.padre
            else:
                nodo.padre.derecha = hijo
                if hijo: hijo.padre = nodo.padre
        else:
            # Tiene dos hijos, buscar el sucesor (menor nodo en el subárbol derecho)
            sucesor = self._minValueNode(nodo.derecha)
            clave_sucesor = sucesor.clave
            self._eliminar(sucesor)  # Eliminar el sucesor
            # Reemplazar el nodo a eliminar con el sucesor
            nodo.clave = sucesor.clave
            nodo.p1 = sucesor.p1
            nodo.p2 = sucesor.p2
            # Asegurarse de que el diccionario apunte al nodo actualizado
            nodos_por_clave[clave_sucesor] = nodo
            del nodos_por_clave[sucesor.clave]

    def _minValueNode(self, nodo):
        current = nodo
        while current.izquierda is not None:
            current = current.izquierda
        return current
        

    def swap(self, clave1, clave2):
        nodo1 = nodos_por_clave[clave1]
        nodo2 = nodos_por_clave[clave2]
        
        t_clave = nodo1.clave
        t_p1 = nodo1.p1
        t_p2 = nodo1.p2
    
        nodo1.clave = nodo2.clave
        nodo1.p1 = nodo2.p1
        nodo1.p2 = nodo2.p2

        nodo2.clave = t_clave
        nodo2.p1 = t_p1
        nodo2.p2 = t_p2
        

    # Método para imprimir el Treap (Para propósitos de depuración y visualización)
    def imprimir(self, nodo=None, nivel=0, prefijo="Raíz: "):
        if nodo is None:
            nodo = self.raiz

        print(" " * nivel * 2 + prefijo + str(nodo.clave) + " (" + str(nodo.prioridad) + ")")
        if nodo.izquierda is not None:
            self.imprimir(nodo.izquierda, nivel + 1, "Izq: ")
        if nodo.derecha is not None:
            self.imprimir(nodo.derecha, nivel + 1, "Der: ")

# %%
# Demostración
treap = Treap()
treap.insertar(1, [9, 14], [3, 8])
print("Primera:")
treap.imprimir()
treap.insertar(2, [4, 11], [8, 5])
print("\nSegundaa:")
treap.imprimir()
treap.insertar(3, [9, 7], [5, 3])
print("\nTercera:")
treap.imprimir()
treap.insertar(4, [6, 4], [8, 2])
print("\nFinal:")
treap.imprimir()
# Out:
# Primera:
# Raíz: 1 (0.28301843497395607)
#
# Segundaa:
# Raíz: 2 (0.5392567021723635)
#   Izq: 1 (0.28301843497395607)
#
# Tercera:
# Raíz: 3 (0.7652934834581636)
#   Der: 2 (0.5392567021723635)
#     Izq: 1 (0.28301843497395607)
#
# Final:
# Raíz: 3 (0.7652934834581636)
#   Izq: 4 (0.18741421405957437)
#   Der: 2 (0.5392567021723635)
#     Izq: 1 (0.28301843497395607)

# %%
treap.imprimir()

treap.eliminar(4)
print("\nFinal:")
treap.imprimir()
# Out:
# Raíz: 3 (0.7652934834581636)
#   Izq: 4 (0.18741421405957437)
#   Der: 2 (0.5392567021723635)
#     Izq: 1 (0.28301843497395607)
#
# Final:
# Raíz: 3 (0.7652934834581636)
#   Der: 2 (0.5392567021723635)
#     Izq: 1 (0.28301843497395607)

# %%
treap.swap(3, 1)
print("\nFinal:")
treap.imprimir()
# Out:
# Final:
# Raíz: 1 (0.4216070405209721)
#   Izq: 4 (0.2119712979899041)
#   Der: 2 (0.22374573538759124)
#     Izq: 3 (0.09733499187769923)
